# %%
import torch
from torch import nn
from torch.utils.data import Dataset
from torchvision import transforms

import pytorch_lightning as pl
from torch.utils.data import DataLoader, random_split

import torch.optim as optim
import torch.ao.quantization as quant
import pytorch_lightning as pl
from torchvision.models import resnet1

import cv2
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path
import os
import sys
import time

sys.path.append(str(Path("../src").resolve()))
from spectogram_datamodule import SpektogramDataModule
from custom_transform import ShuffleChannels

FOLDER_PATH = Path(r"../spectogram_wieliczka")
TEST_FOLDER_PATH = Path(r"../spectogram_ziemowit")
NUM_CLASSES = 2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2b0672ed6e91> in <module>
#       2 from torch import nn
#       3 from torch.utils.data import Dataset
# ----> 4 from torchvision import transforms
#       5
#       6 # import pytorch_lightning as pl
#
# ModuleNotFoundError: No module named 'torchvision'

# %%
spectrogram_transforms = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Resize((224, 224)), 
    transforms.Normalize(mean=[0.5, 0.5, 0.5],
                         std=[0.5, 0.5, 0.5]),
    ShuffleChannels(0.5)
])

dm_wieliczka = SpektogramDataModule(FOLDER_PATH, spectrogram_transforms)
dm_wieliczka.setup()

dm_ziemowit = SpektogramDataModule(TEST_FOLDER_PATH, spectrogram_transforms, test_split=1, num_workers=0)
dm_ziemowit.setup()


plt.imshow(next(iter(dm_wieliczka.train_dataloader()))[0][3].numpy().transpose(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.0..1.0].

# %%
class LitResNet(pl.LightningModule):
	def __init__(self, num_classes=10, lr=1e-3):
		super().__init__()
		self.save_hyperparameters()
		self.lr = lr

		self.model = resnet18(pretrained=False, num_classes=num_classes)
		self.criterion = nn.CrossEntropyLoss()


		self.train_loss_history = []
		self.train_acc_history = []

		self.val_loss_history = []
		self.val_acc_history = []

		self.test_loss_history = []
		self.test_acc_history = []

	def forward(self, x):
		# return self.model(x)
		x = self.model.conv1(x)
		x = self.model.bn1(x)
		x = self.model.relu(x)
		x = self.model.maxpool(x)
		x = self.model.layer1(x)
		x = self.model.layer2(x)
		x = self.model.layer3(x)
		x = self.model.layer4(x)
		x = self.model.avgpool(x)
		x = torch.flatten(x, 1)
		x = self.model.fc(x)

		return x



	def training_step(self, batch, batch_idx):
		x, y = batch
		y_hat = self(x)
		loss = self.criterion(y_hat, y)
		acc = (y_hat.argmax(dim=1) == y).float().mean()

		self.log("train_loss", loss, on_step=True, on_epoch=True, prog_bar=True)
		self.log("train_acc", acc, on_step=True, on_epoch=True, prog_bar=True)

		self.train_loss_history.append(loss.detach().cpu())
		self.train_acc_history.append(acc.detach().cpu())

		return loss


	def validation_step(self, batch, batch_idx):
		x, y = batch
		y_hat = self(x)
		loss = self.criterion(y_hat, y)
		acc = (y_hat.argmax(dim=1) == y).float().mean()
		self.val_loss_history.append(loss.detach().cpu())
		self.val_acc_history.append(acc.detach().cpu())
		self.log("val_loss", loss, on_epoch=True, prog_bar=True)
		self.log("val_acc", acc, on_epoch=True, prog_bar=True)
		return loss

	def test_step(self, batch, batch_idx):
		x, y = batch
		start_time = time.time()  
		
		y_hat = self(x)
		loss = self.criterion(y_hat, y)
		acc = (y_hat.argmax(dim=1) == y).float().mean()
		
		end_time = time.time()  
		
		batch_time = end_time - start_time  
		batch_size = x.size(0)
		fps = batch_size / batch_time  
		
		self.test_loss_history.append(loss.detach().cpu())
		self.test_acc_history.append(acc.detach().cpu())

		self.log("test_loss", loss, on_epoch=True, prog_bar=True)
		self.log("test_acc", acc, on_epoch=True, prog_bar=True)
		self.log("test_fps", fps, on_epoch=True, prog_bar=True)  
		
		return loss

	def configure_optimizers(self):
		return optim.SGD(self.parameters(), lr=self.lr, momentum=0.9)

# %%
model = LitResNet(num_classes=NUM_CLASSES, lr=1e-3)

trainer = pl.Trainer(
    precision=16,
    accelerator='gpu',
    devices=1,
    max_epochs=50
)

trainer.fit(model, dm_wieliczka)
# Out:
# Using 16bit Automatic Mixed Precision (AMP)
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type             | Params | Mode  | FLOPs
# ---------------------------------------------------------------
# 0 | model     | ResNet           | 11.2 M | train | 0
# 1 | criterion | CrossEntropyLoss | 0      | train | 0
# ---------------------------------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.710    Total estimated model params size (MB)
# 69        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Epoch 49: 100%|██████████| 5/5 [00:01<00:00,  3.40it/s, v_num=9, train_loss_step=0.111, train_acc_step=0.941, val_loss=0.123, val_acc=0.927, train_loss_epoch=0.0995, train_acc_epoch=0.959]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 49: 100%|██████████| 5/5 [00:02<00:00,  2.15it/s, v_num=9, train_loss_step=0.111, train_acc_step=0.941, val_loss=0.123, val_acc=0.927, train_loss_epoch=0.0995, train_acc_epoch=0.959]

# %%
import matplotlib.pyplot as plt

# Loss
plt.figure(figsize=(8,4))
plt.plot(model.train_loss_history, label="train_loss")
plt.plot(model.val_loss_history, label="val_loss")
plt.xlabel("Batch")
plt.ylabel("Loss")
plt.title("Loss podczas treningu")
plt.legend()
plt.show()

# Accuracy
plt.figure(figsize=(8,4))
plt.plot(model.train_acc_history, label="train_acc")
plt.plot(model.val_acc_history, label="val_acc")
plt.xlabel("Batch")
plt.ylabel("Accuracy")
plt.title("Accuracy podczas treningu")
plt.legend()
plt.show()

# %%
trainer.test(model, dm_ziemowit)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 20.90it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.32258063554763794
#         test_fps             1497.12060546875
#         test_loss            5.543695449829102
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_loss': 5.543695449829102,
#   'test_acc': 0.32258063554763794,
#   'test_fps': 1497.12060546875}]

# %%
# sample = next(iter(dm_ziemowit.test_dataloader()))[0][0]
# sample = sample.unsqueeze(0).cuda().half() 

# model.eval().cuda()

# trt_model = torch_tensorrt.compile(
#     model,
#     inputs=[torch_tensorrt.Input(sample.shape, dtype=torch.half)],
#     enabled_precisions={torch.half},
#     workspace_size=1 << 20
# )

# with torch.no_grad():
#     out = trt_model(sample)
# print(out.shape)

# %%
next(iter(dm_ziemowit.test_dataloader()))[0][0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
sample = next(iter(dm_ziemowit.test_dataloader()))[0][0].unsqueeze(0).cuda().half()

model = model.eval().cuda().half()

torch.onnx.export(
    model,
    sample,
    "models/resnet18.onnx",
    input_names=["input"],
    output_names=["output"],
    opset_version=11,          
    dynamic_axes={"input": {0: "batch_size"}, "output": {0: "batch_size"}},
    do_constant_folding=True,     
)
# Out:
# W0117 15:06:59.864000 726466 torch/onnx/_internal/exporter/_compat.py:114] Setting ONNX exporter to use operator set version 18 because the requested opset_version 12 is a lower version than we have implementations for. Automatic version conversion will be performed, which may not be successful at converting to the requested version. If version conversion is unsuccessful, the opset version of the exported model will be kept at 18. Please consider setting opset_version >=18 to leverage latest ONNX features
# [torch.onnx] Obtain model graph for `LitResNet([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `LitResNet([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# The model version conversion is not supported by the onnxscript version converter and fallback is enabled. The model will be converted using the onnx C API (target version: 12).
# [torch.onnx] Translate the graph into ONNX... ✅
# Failed to convert the model to the target version 12 using the ONNX C API. The model was not modified
# Traceback (most recent call last):
#   File "/home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/onnxscript/version_converter/__init__.py", line 127, in call
#     converted_proto = _c_api_utils.call_onnx_api(
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/onnxscript/version_converter/_c_api_utils.py", line 65, in call_onnx_api
#     result = func(proto)
#              ^^^^^^^^^^^
#   File "/home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/onnxscript/version_converter/__init__.py", line 122, in _partial_convert_version
#     return onnx.version_converter.convert_version(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/onnx/version_converter.py", line 39, in convert_version
#     converted_model_str = C.convert_version(model_str, target_version)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: /github/workspace/onnx/version_converter/adapters/axes_input_to_attribute.h:65: adapt: Assertion `node->hasAttribute(kaxes)` failed: No initializer or constant input to node found
# Applied 40 of general pattern rewrite rules.
# ONNXProgram(
#     model=
#         <
#             ir_version=10,
#             opset_imports={'': 18},
#             producer_name='pytorch',
#             producer_version='2.9.1+cu126',
#             domain=None,
#             model_version=None,
#         >
#         graph(
#             name=main_graph,
#             inputs=(
#                 %"input"<FLOAT16,[s77,3,224,224]>
#             ),
#             outputs=(
#                 %"output"<FLOAT16,[1,2]>
#             ),
#             initializers=(
#                 %"model.fc.bias"<FLOAT16,[2]>{TorchTensor<FLOAT16,[2]>(Parameter containing: tensor([-0.0018,  0.0092], device='cuda:0', dtype=torch.float16, requires_grad=True), name='model.fc.bias')},
#                 %"model.conv1.weight"<FLOAT16,[64,3,7,7]>{Tensor(...)},
#                 %"model.layer1.0.conv1.weight"<FLOAT16,[64,64,3,3]>{Tensor(...)},
#                 %"model.layer1.0.conv2.weight"<FLOAT16,[64,64,3,3]>{Tensor(...)},
#                 %"model.layer1.1.conv1.weight"<FLOAT16,[64,64,3,3]>{Tensor(...)},
#                 %"model.layer1.1.conv2.weight"<FLOAT16,[64,64,3,3]>{Tensor(...)},
#                 %"model.layer2.0.conv1.weight"<FLOAT16,[128,64,3,3]>{Tensor(...)},
#                 %"model.layer2.0.conv2.weight"<FLOAT16,[128,128,3,3]>{Tensor(...)},
#                 %"model.layer2.0.downsample.0.weight"<FLOAT16,[128,64,1,1]>{Tensor(...)},
#                 %"model.layer2.1.conv1.weight"<FLOAT16,[128,128,3,3]>{Tensor(...)},
#                 %"model.layer2.1.conv2.weight"<FLOAT16,[128,128,3,3]>{Tensor(...)},
#                 %"model.layer3.0.conv1.weight"<FLOAT16,[256,128,3,3]>{Tensor(...)},
#                 %"model.layer3.0.conv2.weight"<FLOAT16,[256,256,3,3]>{Tensor(...)},
#                 %"model.layer3.0.downsample.0.weight"<FLOAT16,[256,128,1,1]>{Tensor(...)},
#                 %"model.layer3.1.conv1.weight"<FLOAT16,[256,256,3,3]>{Tensor(...)},
#                 %"model.layer3.1.conv2.weight"<FLOAT16,[256,256,3,3]>{Tensor(...)},
#                 %"model.layer4.0.conv1.weight"<FLOAT16,[512,256,3,3]>{Tensor(...)},
#                 %"model.layer4.0.conv2.weight"<FLOAT16,[512,512,3,3]>{Tensor(...)},
#                 %"model.layer4.0.downsample.0.weight"<FLOAT16,[512,256,1,1]>{Tensor(...)},
#                 %"model.layer4.1.conv1.weight"<FLOAT16,[512,512,3,3]>{Tensor(...)},
#                 %"model.layer4.1.conv2.weight"<FLOAT16,[512,512,3,3]>{Tensor(...)},
#                 %"model.fc.weight"<FLOAT16,[2,512]>{TorchTensor(...)},
#                 %"val_186"<INT64,[2]>{Tensor<INT64,[2]>(array([-1, -2]), name='val_186')},
#                 %"val_190"<INT64,[2]>{Tensor<INT64,[2]>(array([  1, 512]), name='val_190')},
#                 %"model.conv1.weight_bias"<FLOAT16,[64]>{Tensor(...)},
#                 %"model.layer1.0.conv1.weight_bias"<FLOAT16,[64]>{Tensor(...)},
#                 %"model.layer1.0.conv2.weight_bias"<FLOAT16,[64]>{Tensor(...)},
#                 %"model.layer1.1.conv1.weight_bias"<FLOAT16,[64]>{Tensor(...)},
#                 %"model.layer1.1.conv2.weight_bias"<FLOAT16,[64]>{Tensor(...)},
#                 %"model.layer2.0.conv1.weight_bias"<FLOAT16,[128]>{Tensor(...)},
#                 %"model.layer2.0.conv2.weight_bias"<FLOAT16,[128]>{Tensor(...)},
#                 %"model.layer2.0.downsample.0.weight_bias"<FLOAT16,[128]>{Tensor(...)},
#                 %"model.layer2.1.conv1.weight_bias"<FLOAT16,[128]>{Tensor(...)},
#                 %"model.layer2.1.conv2.weight_bias"<FLOAT16,[128]>{Tensor(...)},
#                 %"model.layer3.0.conv1.weight_bias"<FLOAT16,[256]>{Tensor(...)},
#                 %"model.layer3.0.conv2.weight_bias"<FLOAT16,[256]>{Tensor(...)},
#                 %"model.layer3.0.downsample.0.weight_bias"<FLOAT16,[256]>{Tensor(...)},
#                 %"model.layer3.1.conv1.weight_bias"<FLOAT16,[256]>{Tensor(...)},
#                 %"model.layer3.1.conv2.weight_bias"<FLOAT16,[256]>{Tensor(...)},
#                 %"model.layer4.0.conv1.weight_bias"<FLOAT16,[512]>{Tensor(...)},
#                 %"model.layer4.0.conv2.weight_bias"<FLOAT16,[512]>{Tensor(...)},
#                 %"model.layer4.0.downsample.0.weight_bias"<FLOAT16,[512]>{Tensor(...)},
#                 %"model.layer4.1.conv1.weight_bias"<FLOAT16,[512]>{Tensor(...)},
#                 %"model.layer4.1.conv2.weight_bias"<FLOAT16,[512]>{Tensor(...)}
#             ),
#         ) {
#              0 |  # node_Conv_251
#                   %"getitem"<FLOAT16,[1,64,112,112]> ⬅️ ::Conv(%"input", %"model.conv1.weight"{...}, %"model.conv1.weight_bias"{...}) {group=1, pads=(3, 3, 3, 3), auto_pad='NOTSET', strides=(2, 2), dilations=(1, 1)}
#              1 |  # node_relu
#                   %"relu"<FLOAT16,[1,64,112,112]> ⬅️ ::Relu(%"getitem")
#              2 |  # node_max_pool2d
#                   %"max_pool2d"<FLOAT16,[1,64,56,56]> ⬅️ ::MaxPool(%"relu") {storage_order=0, dilations=(1, 1), ceil_mode=0, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(2, 2), kernel_shape=(3, 3)}
#              3 |  # node_Conv_253
#                   %"getitem_3"<FLOAT16,[1,64,56,56]> ⬅️ ::Conv(%"max_pool2d", %"model.layer1.0.conv1.weight"{...}, %"model.layer1.0.conv1.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#              4 |  # node_relu_1
#                   %"relu_1"<FLOAT16,[1,64,56,56]> ⬅️ ::Relu(%"getitem_3")
#              5 |  # node_Conv_255
#                   %"getitem_6"<FLOAT16,[1,64,56,56]> ⬅️ ::Conv(%"relu_1", %"model.layer1.0.conv2.weight"{...}, %"model.layer1.0.conv2.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#              6 |  # node_add_5
#                   %"add_5"<FLOAT16,[1,64,56,56]> ⬅️ ::Add(%"getitem_6", %"max_pool2d")
#              7 |  # node_relu_2
#                   %"relu_2"<FLOAT16,[1,64,56,56]> ⬅️ ::Relu(%"add_5")
#              8 |  # node_Conv_257
#                   %"getitem_9"<FLOAT16,[1,64,56,56]> ⬅️ ::Conv(%"relu_2", %"model.layer1.1.conv1.weight"{...}, %"model.layer1.1.conv1.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#              9 |  # node_relu_3
#                   %"relu_3"<FLOAT16,[1,64,56,56]> ⬅️ ::Relu(%"getitem_9")
#             10 |  # node_Conv_259
#                   %"getitem_12"<FLOAT16,[1,64,56,56]> ⬅️ ::Conv(%"relu_3", %"model.layer1.1.conv2.weight"{...}, %"model.layer1.1.conv2.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             11 |  # node_add_6
#                   %"add_6"<FLOAT16,[1,64,56,56]> ⬅️ ::Add(%"getitem_12", %"relu_2")
#             12 |  # node_relu_4
#                   %"relu_4"<FLOAT16,[1,64,56,56]> ⬅️ ::Relu(%"add_6")
#             13 |  # node_Conv_261
#                   %"getitem_15"<FLOAT16,[1,128,28,28]> ⬅️ ::Conv(%"relu_4", %"model.layer2.0.conv1.weight"{...}, %"model.layer2.0.conv1.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(2, 2), dilations=(1, 1)}
#             14 |  # node_relu_5
#                   %"relu_5"<FLOAT16,[1,128,28,28]> ⬅️ ::Relu(%"getitem_15")
#             15 |  # node_Conv_263
#                   %"getitem_18"<FLOAT16,[1,128,28,28]> ⬅️ ::Conv(%"relu_5", %"model.layer2.0.conv2.weight"{...}, %"model.layer2.0.conv2.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             16 |  # node_Conv_265
#                   %"getitem_21"<FLOAT16,[1,128,28,28]> ⬅️ ::Conv(%"relu_4", %"model.layer2.0.downsample.0.weight"{...}, %"model.layer2.0.downsample.0.weight_bias"{...}) {group=1, pads=(0, 0, 0, 0), auto_pad='NOTSET', strides=(2, 2), dilations=(1, 1)}
#             17 |  # node_add_7
#                   %"add_7"<FLOAT16,[1,128,28,28]> ⬅️ ::Add(%"getitem_18", %"getitem_21")
#             18 |  # node_relu_6
#                   %"relu_6"<FLOAT16,[1,128,28,28]> ⬅️ ::Relu(%"add_7")
#             19 |  # node_Conv_267
#                   %"getitem_24"<FLOAT16,[1,128,28,28]> ⬅️ ::Conv(%"relu_6", %"model.layer2.1.conv1.weight"{...}, %"model.layer2.1.conv1.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             20 |  # node_relu_7
#                   %"relu_7"<FLOAT16,[1,128,28,28]> ⬅️ ::Relu(%"getitem_24")
#             21 |  # node_Conv_269
#                   %"getitem_27"<FLOAT16,[1,128,28,28]> ⬅️ ::Conv(%"relu_7", %"model.layer2.1.conv2.weight"{...}, %"model.layer2.1.conv2.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             22 |  # node_add_8
#                   %"add_8"<FLOAT16,[1,128,28,28]> ⬅️ ::Add(%"getitem_27", %"relu_6")
#             23 |  # node_relu_8
#                   %"relu_8"<FLOAT16,[1,128,28,28]> ⬅️ ::Relu(%"add_8")
#             24 |  # node_Conv_271
#                   %"getitem_30"<FLOAT16,[1,256,14,14]> ⬅️ ::Conv(%"relu_8", %"model.layer3.0.conv1.weight"{...}, %"model.layer3.0.conv1.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(2, 2), dilations=(1, 1)}
#             25 |  # node_relu_9
#                   %"relu_9"<FLOAT16,[1,256,14,14]> ⬅️ ::Relu(%"getitem_30")
#             26 |  # node_Conv_273
#                   %"getitem_33"<FLOAT16,[1,256,14,14]> ⬅️ ::Conv(%"relu_9", %"model.layer3.0.conv2.weight"{...}, %"model.layer3.0.conv2.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             27 |  # node_Conv_275
#                   %"getitem_36"<FLOAT16,[1,256,14,14]> ⬅️ ::Conv(%"relu_8", %"model.layer3.0.downsample.0.weight"{...}, %"model.layer3.0.downsample.0.weight_bias"{...}) {group=1, pads=(0, 0, 0, 0), auto_pad='NOTSET', strides=(2, 2), dilations=(1, 1)}
#             28 |  # node_add_9
#                   %"add_9"<FLOAT16,[1,256,14,14]> ⬅️ ::Add(%"getitem_33", %"getitem_36")
#             29 |  # node_relu_10
#                   %"relu_10"<FLOAT16,[1,256,14,14]> ⬅️ ::Relu(%"add_9")
#             30 |  # node_Conv_277
#                   %"getitem_39"<FLOAT16,[1,256,14,14]> ⬅️ ::Conv(%"relu_10", %"model.layer3.1.conv1.weight"{...}, %"model.layer3.1.conv1.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             31 |  # node_relu_11
#                   %"relu_11"<FLOAT16,[1,256,14,14]> ⬅️ ::Relu(%"getitem_39")
#             32 |  # node_Conv_279
#                   %"getitem_42"<FLOAT16,[1,256,14,14]> ⬅️ ::Conv(%"relu_11", %"model.layer3.1.conv2.weight"{...}, %"model.layer3.1.conv2.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             33 |  # node_add_10
#                   %"add_10"<FLOAT16,[1,256,14,14]> ⬅️ ::Add(%"getitem_42", %"relu_10")
#             34 |  # node_relu_12
#                   %"relu_12"<FLOAT16,[1,256,14,14]> ⬅️ ::Relu(%"add_10")
#             35 |  # node_Conv_281
#                   %"getitem_45"<FLOAT16,[1,512,7,7]> ⬅️ ::Conv(%"relu_12", %"model.layer4.0.conv1.weight"{...}, %"model.layer4.0.conv1.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(2, 2), dilations=(1, 1)}
#             36 |  # node_relu_13
#                   %"relu_13"<FLOAT16,[1,512,7,7]> ⬅️ ::Relu(%"getitem_45")
#             37 |  # node_Conv_283
#                   %"getitem_48"<FLOAT16,[1,512,7,7]> ⬅️ ::Conv(%"relu_13", %"model.layer4.0.conv2.weight"{...}, %"model.layer4.0.conv2.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             38 |  # node_Conv_285
#                   %"getitem_51"<FLOAT16,[1,512,7,7]> ⬅️ ::Conv(%"relu_12", %"model.layer4.0.downsample.0.weight"{...}, %"model.layer4.0.downsample.0.weight_bias"{...}) {group=1, pads=(0, 0, 0, 0), auto_pad='NOTSET', strides=(2, 2), dilations=(1, 1)}
#             39 |  # node_add_11
#                   %"add_11"<FLOAT16,[1,512,7,7]> ⬅️ ::Add(%"getitem_48", %"getitem_51")
#             40 |  # node_relu_14
#                   %"relu_14"<FLOAT16,[1,512,7,7]> ⬅️ ::Relu(%"add_11")
#             41 |  # node_Conv_287
#                   %"getitem_54"<FLOAT16,[1,512,7,7]> ⬅️ ::Conv(%"relu_14", %"model.layer4.1.conv1.weight"{...}, %"model.layer4.1.conv1.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             42 |  # node_relu_15
#                   %"relu_15"<FLOAT16,[1,512,7,7]> ⬅️ ::Relu(%"getitem_54")
#             43 |  # node_Conv_289
#                   %"getitem_57"<FLOAT16,[1,512,7,7]> ⬅️ ::Conv(%"relu_15", %"model.layer4.1.conv2.weight"{...}, %"model.layer4.1.conv2.weight_bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             44 |  # node_add_12
#                   %"add_12"<FLOAT16,[1,512,7,7]> ⬅️ ::Add(%"getitem_57", %"relu_14")
#             45 |  # node_relu_16
#                   %"relu_16"<FLOAT16,[1,512,7,7]> ⬅️ ::Relu(%"add_12")
#             46 |  # node_mean
#                   %"mean"<FLOAT16,[1,512,1,1]> ⬅️ ::ReduceMean(%"relu_16", %"val_186"{[-1, -2]}) {noop_with_empty_axes=0, keepdims=1}
#             47 |  # node_view
#                   %"view"<FLOAT16,[1,512]> ⬅️ ::Reshape(%"mean", %"val_190"{[1, 512]}) {allowzero=1}
#             48 |  # node_linear
#                   %"output"<FLOAT16,[1,2]> ⬅️ ::Gemm(%"view", %"model.fc.weight"{...}, %"model.fc.bias"{[-0.0018053054809570312, 0.0091552734375]}) {beta=1.0, transB=1, alpha=1.0, transA=0}
#             return %"output"<FLOAT16,[1,2]>
#         }
#
#
#     ,
#     exported_program=
#         ExportedProgram:
#             class GraphModule(torch.nn.Module):
#                 def forward(self, p_model_conv1_weight: "f16[64, 3, 7, 7]", p_model_bn1_weight: "f16[64]", p_model_bn1_bias: "f16[64]", p_model_layer1_0_conv1_weight: "f16[64, 64, 3, 3]", p_model_layer1_0_bn1_weight: "f16[64]", p_model_layer1_0_bn1_bias: "f16[64]", p_model_layer1_0_conv2_weight: "f16[64, 64, 3, 3]", p_model_layer1_0_bn2_weight: "f16[64]", p_model_layer1_0_bn2_bias: "f16[64]", p_model_layer1_1_conv1_weight: "f16[64, 64, 3, 3]", p_model_layer1_1_bn1_weight: "f16[64]", p_model_layer1_1_bn1_bias: "f16[64]", p_model_layer1_1_conv2_weight: "f16[64, 64, 3, 3]", p_model_layer1_1_bn2_weight: "f16[64]", p_model_layer1_1_bn2_bias: "f16[64]", p_model_layer2_0_conv1_weight: "f16[128, 64, 3, 3]", p_model_layer2_0_bn1_weight: "f16[128]", p_model_layer2_0_bn1_bias: "f16[128]", p_model_layer2_0_conv2_weight: "f16[128, 128, 3, 3]", p_model_layer2_0_bn2_weight: "f16[128]", p_model_layer2_0_bn2_bias: "f16[128]", p_model_layer2_0_downsample_0_weight: "f16[128, 64, 1, 1]", p_model_layer2_0_downsample_1_weight: "f16[128]", p_model_layer2_0_downsample_1_bias: "f16[128]", p_model_layer2_1_conv1_weight: "f16[128, 128, 3, 3]", p_model_layer2_1_bn1_weight: "f16[128]", p_model_layer2_1_bn1_bias: "f16[128]", p_model_layer2_1_conv2_weight: "f16[128, 128, 3, 3]", p_model_layer2_1_bn2_weight: "f16[128]", p_model_layer2_1_bn2_bias: "f16[128]", p_model_layer3_0_conv1_weight: "f16[256, 128, 3, 3]", p_model_layer3_0_bn1_weight: "f16[256]", p_model_layer3_0_bn1_bias: "f16[256]", p_model_layer3_0_conv2_weight: "f16[256, 256, 3, 3]", p_model_layer3_0_bn2_weight: "f16[256]", p_model_layer3_0_bn2_bias: "f16[256]", p_model_layer3_0_downsample_0_weight: "f16[256, 128, 1, 1]", p_model_layer3_0_downsample_1_weight: "f16[256]", p_model_layer3_0_downsample_1_bias: "f16[256]", p_model_layer3_1_conv1_weight: "f16[256, 256, 3, 3]", p_model_layer3_1_bn1_weight: "f16[256]", p_model_layer3_1_bn1_bias: "f16[256]", p_model_layer3_1_conv2_weight: "f16[256, 256, 3, 3]", p_model_layer3_1_bn2_weight: "f16[256]", p_model_layer3_1_bn2_bias: "f16[256]", p_model_layer4_0_conv1_weight: "f16[512, 256, 3, 3]", p_model_layer4_0_bn1_weight: "f16[512]", p_model_layer4_0_bn1_bias: "f16[512]", p_model_layer4_0_conv2_weight: "f16[512, 512, 3, 3]", p_model_layer4_0_bn2_weight: "f16[512]", p_model_layer4_0_bn2_bias: "f16[512]", p_model_layer4_0_downsample_0_weight: "f16[512, 256, 1, 1]", p_model_layer4_0_downsample_1_weight: "f16[512]", p_model_layer4_0_downsample_1_bias: "f16[512]", p_model_layer4_1_conv1_weight: "f16[512, 512, 3, 3]", p_model_layer4_1_bn1_weight: "f16[512]", p_model_layer4_1_bn1_bias: "f16[512]", p_model_layer4_1_conv2_weight: "f16[512, 512, 3, 3]", p_model_layer4_1_bn2_weight: "f16[512]", p_model_layer4_1_bn2_bias: "f16[512]", p_model_fc_weight: "f16[2, 512]", p_model_fc_bias: "f16[2]", b_model_bn1_running_mean: "f16[64]", b_model_bn1_running_var: "f16[64]", b_model_bn1_num_batches_tracked: "i64[]", b_model_layer1_0_bn1_running_mean: "f16[64]", b_model_layer1_0_bn1_running_var: "f16[64]", b_model_layer1_0_bn1_num_batches_tracked: "i64[]", b_model_layer1_0_bn2_running_mean: "f16[64]", b_model_layer1_0_bn2_running_var: "f16[64]", b_model_layer1_0_bn2_num_batches_tracked: "i64[]", b_model_layer1_1_bn1_running_mean: "f16[64]", b_model_layer1_1_bn1_running_var: "f16[64]", b_model_layer1_1_bn1_num_batches_tracked: "i64[]", b_model_layer1_1_bn2_running_mean: "f16[64]", b_model_layer1_1_bn2_running_var: "f16[64]", b_model_layer1_1_bn2_num_batches_tracked: "i64[]", b_model_layer2_0_bn1_running_mean: "f16[128]", b_model_layer2_0_bn1_running_var: "f16[128]", b_model_layer2_0_bn1_num_batches_tracked: "i64[]", b_model_layer2_0_bn2_running_mean: "f16[128]", b_model_layer2_0_bn2_running_var: "f16[128]", b_model_layer2_0_bn2_num_batches_tracked: "i64[]", b_model_layer2_0_downsample_1_running_mean: "f16[128]", b_model_layer2_0_downsample_1_running_var: "f16[128]", b_model_layer2_0_downsample_1_num_batches_tracked: "i64[]", b_model_layer2_1_bn1_running_mean: "f16[128]", b_model_lay ...
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d: "f16[s77, 64, 112, 112]" = torch.ops.aten.conv2d.default(x, p_model_conv1_weight, None, [2, 2], [3, 3]);  x = p_model_conv1_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d, p_model_bn1_weight, p_model_bn1_bias, b_model_bn1_running_mean, b_model_bn1_running_var, 0.1, 1e-05);  conv2d = p_model_bn1_weight = p_model_bn1_bias = b_model_bn1_running_mean = b_model_bn1_running_var = None
#                     getitem: "f16[1, 64, 112, 112]" = _native_batch_norm_legit_no_training[0];  _native_batch_norm_legit_no_training = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu: "f16[1, 64, 112, 112]" = torch.ops.aten.relu.default(getitem);  getitem = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/pooling.py:226 in forward, code: return F.max_pool2d(
#                     max_pool2d: "f16[1, 64, 56, 56]" = torch.ops.aten.max_pool2d.default(relu, [3, 3], [2, 2], [1, 1]);  relu = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_1: "f16[1, 64, 56, 56]" = torch.ops.aten.conv2d.default(max_pool2d, p_model_layer1_0_conv1_weight, None, [1, 1], [1, 1]);  p_model_layer1_0_conv1_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_1 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_1, p_model_layer1_0_bn1_weight, p_model_layer1_0_bn1_bias, b_model_layer1_0_bn1_running_mean, b_model_layer1_0_bn1_running_var, 0.1, 1e-05);  conv2d_1 = p_model_layer1_0_bn1_weight = p_model_layer1_0_bn1_bias = b_model_layer1_0_bn1_running_mean = b_model_layer1_0_bn1_running_var = None
#                     getitem_3: "f16[1, 64, 56, 56]" = _native_batch_norm_legit_no_training_1[0];  _native_batch_norm_legit_no_training_1 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_1: "f16[1, 64, 56, 56]" = torch.ops.aten.relu.default(getitem_3);  getitem_3 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_2: "f16[1, 64, 56, 56]" = torch.ops.aten.conv2d.default(relu_1, p_model_layer1_0_conv2_weight, None, [1, 1], [1, 1]);  relu_1 = p_model_layer1_0_conv2_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_2 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_2, p_model_layer1_0_bn2_weight, p_model_layer1_0_bn2_bias, b_model_layer1_0_bn2_running_mean, b_model_layer1_0_bn2_running_var, 0.1, 1e-05);  conv2d_2 = p_model_layer1_0_bn2_weight = p_model_layer1_0_bn2_bias = b_model_layer1_0_bn2_running_mean = b_model_layer1_0_bn2_running_var = None
#                     getitem_6: "f16[1, 64, 56, 56]" = _native_batch_norm_legit_no_training_2[0];  _native_batch_norm_legit_no_training_2 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torchvision/models/resnet.py:102 in forward, code: out += identity
#                     add_5: "f16[1, 64, 56, 56]" = torch.ops.aten.add.Tensor(getitem_6, max_pool2d);  getitem_6 = max_pool2d = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_2: "f16[1, 64, 56, 56]" = torch.ops.aten.relu.default(add_5);  add_5 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_3: "f16[1, 64, 56, 56]" = torch.ops.aten.conv2d.default(relu_2, p_model_layer1_1_conv1_weight, None, [1, 1], [1, 1]);  p_model_layer1_1_conv1_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_3 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_3, p_model_layer1_1_bn1_weight, p_model_layer1_1_bn1_bias, b_model_layer1_1_bn1_running_mean, b_model_layer1_1_bn1_running_var, 0.1, 1e-05);  conv2d_3 = p_model_layer1_1_bn1_weight = p_model_layer1_1_bn1_bias = b_model_layer1_1_bn1_running_mean = b_model_layer1_1_bn1_running_var = None
#                     getitem_9: "f16[1, 64, 56, 56]" = _native_batch_norm_legit_no_training_3[0];  _native_batch_norm_legit_no_training_3 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_3: "f16[1, 64, 56, 56]" = torch.ops.aten.relu.default(getitem_9);  getitem_9 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_4: "f16[1, 64, 56, 56]" = torch.ops.aten.conv2d.default(relu_3, p_model_layer1_1_conv2_weight, None, [1, 1], [1, 1]);  relu_3 = p_model_layer1_1_conv2_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_4 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_4, p_model_layer1_1_bn2_weight, p_model_layer1_1_bn2_bias, b_model_layer1_1_bn2_running_mean, b_model_layer1_1_bn2_running_var, 0.1, 1e-05);  conv2d_4 = p_model_layer1_1_bn2_weight = p_model_layer1_1_bn2_bias = b_model_layer1_1_bn2_running_mean = b_model_layer1_1_bn2_running_var = None
#                     getitem_12: "f16[1, 64, 56, 56]" = _native_batch_norm_legit_no_training_4[0];  _native_batch_norm_legit_no_training_4 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torchvision/models/resnet.py:102 in forward, code: out += identity
#                     add_6: "f16[1, 64, 56, 56]" = torch.ops.aten.add.Tensor(getitem_12, relu_2);  getitem_12 = relu_2 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_4: "f16[1, 64, 56, 56]" = torch.ops.aten.relu.default(add_6);  add_6 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_5: "f16[1, 128, 28, 28]" = torch.ops.aten.conv2d.default(relu_4, p_model_layer2_0_conv1_weight, None, [2, 2], [1, 1]);  p_model_layer2_0_conv1_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_5 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_5, p_model_layer2_0_bn1_weight, p_model_layer2_0_bn1_bias, b_model_layer2_0_bn1_running_mean, b_model_layer2_0_bn1_running_var, 0.1, 1e-05);  conv2d_5 = p_model_layer2_0_bn1_weight = p_model_layer2_0_bn1_bias = b_model_layer2_0_bn1_running_mean = b_model_layer2_0_bn1_running_var = None
#                     getitem_15: "f16[1, 128, 28, 28]" = _native_batch_norm_legit_no_training_5[0];  _native_batch_norm_legit_no_training_5 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_5: "f16[1, 128, 28, 28]" = torch.ops.aten.relu.default(getitem_15);  getitem_15 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_6: "f16[1, 128, 28, 28]" = torch.ops.aten.conv2d.default(relu_5, p_model_layer2_0_conv2_weight, None, [1, 1], [1, 1]);  relu_5 = p_model_layer2_0_conv2_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_6 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_6, p_model_layer2_0_bn2_weight, p_model_layer2_0_bn2_bias, b_model_layer2_0_bn2_running_mean, b_model_layer2_0_bn2_running_var, 0.1, 1e-05);  conv2d_6 = p_model_layer2_0_bn2_weight = p_model_layer2_0_bn2_bias = b_model_layer2_0_bn2_running_mean = b_model_layer2_0_bn2_running_var = None
#                     getitem_18: "f16[1, 128, 28, 28]" = _native_batch_norm_legit_no_training_6[0];  _native_batch_norm_legit_no_training_6 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_7: "f16[1, 128, 28, 28]" = torch.ops.aten.conv2d.default(relu_4, p_model_layer2_0_downsample_0_weight, None, [2, 2]);  relu_4 = p_model_layer2_0_downsample_0_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_7 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_7, p_model_layer2_0_downsample_1_weight, p_model_layer2_0_downsample_1_bias, b_model_layer2_0_downsample_1_running_mean, b_model_layer2_0_downsample_1_running_var, 0.1, 1e-05);  conv2d_7 = p_model_layer2_0_downsample_1_weight = p_model_layer2_0_downsample_1_bias = b_model_layer2_0_downsample_1_running_mean = b_model_layer2_0_downsample_1_running_var = None
#                     getitem_21: "f16[1, 128, 28, 28]" = _native_batch_norm_legit_no_training_7[0];  _native_batch_norm_legit_no_training_7 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torchvision/models/resnet.py:102 in forward, code: out += identity
#                     add_7: "f16[1, 128, 28, 28]" = torch.ops.aten.add.Tensor(getitem_18, getitem_21);  getitem_18 = getitem_21 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_6: "f16[1, 128, 28, 28]" = torch.ops.aten.relu.default(add_7);  add_7 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_8: "f16[1, 128, 28, 28]" = torch.ops.aten.conv2d.default(relu_6, p_model_layer2_1_conv1_weight, None, [1, 1], [1, 1]);  p_model_layer2_1_conv1_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_8 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_8, p_model_layer2_1_bn1_weight, p_model_layer2_1_bn1_bias, b_model_layer2_1_bn1_running_mean, b_model_layer2_1_bn1_running_var, 0.1, 1e-05);  conv2d_8 = p_model_layer2_1_bn1_weight = p_model_layer2_1_bn1_bias = b_model_layer2_1_bn1_running_mean = b_model_layer2_1_bn1_running_var = None
#                     getitem_24: "f16[1, 128, 28, 28]" = _native_batch_norm_legit_no_training_8[0];  _native_batch_norm_legit_no_training_8 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_7: "f16[1, 128, 28, 28]" = torch.ops.aten.relu.default(getitem_24);  getitem_24 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_9: "f16[1, 128, 28, 28]" = torch.ops.aten.conv2d.default(relu_7, p_model_layer2_1_conv2_weight, None, [1, 1], [1, 1]);  relu_7 = p_model_layer2_1_conv2_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_9 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_9, p_model_layer2_1_bn2_weight, p_model_layer2_1_bn2_bias, b_model_layer2_1_bn2_running_mean, b_model_layer2_1_bn2_running_var, 0.1, 1e-05);  conv2d_9 = p_model_layer2_1_bn2_weight = p_model_layer2_1_bn2_bias = b_model_layer2_1_bn2_running_mean = b_model_layer2_1_bn2_running_var = None
#                     getitem_27: "f16[1, 128, 28, 28]" = _native_batch_norm_legit_no_training_9[0];  _native_batch_norm_legit_no_training_9 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torchvision/models/resnet.py:102 in forward, code: out += identity
#                     add_8: "f16[1, 128, 28, 28]" = torch.ops.aten.add.Tensor(getitem_27, relu_6);  getitem_27 = relu_6 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_8: "f16[1, 128, 28, 28]" = torch.ops.aten.relu.default(add_8);  add_8 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_10: "f16[1, 256, 14, 14]" = torch.ops.aten.conv2d.default(relu_8, p_model_layer3_0_conv1_weight, None, [2, 2], [1, 1]);  p_model_layer3_0_conv1_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_10 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_10, p_model_layer3_0_bn1_weight, p_model_layer3_0_bn1_bias, b_model_layer3_0_bn1_running_mean, b_model_layer3_0_bn1_running_var, 0.1, 1e-05);  conv2d_10 = p_model_layer3_0_bn1_weight = p_model_layer3_0_bn1_bias = b_model_layer3_0_bn1_running_mean = b_model_layer3_0_bn1_running_var = None
#                     getitem_30: "f16[1, 256, 14, 14]" = _native_batch_norm_legit_no_training_10[0];  _native_batch_norm_legit_no_training_10 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_9: "f16[1, 256, 14, 14]" = torch.ops.aten.relu.default(getitem_30);  getitem_30 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_11: "f16[1, 256, 14, 14]" = torch.ops.aten.conv2d.default(relu_9, p_model_layer3_0_conv2_weight, None, [1, 1], [1, 1]);  relu_9 = p_model_layer3_0_conv2_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_11 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_11, p_model_layer3_0_bn2_weight, p_model_layer3_0_bn2_bias, b_model_layer3_0_bn2_running_mean, b_model_layer3_0_bn2_running_var, 0.1, 1e-05);  conv2d_11 = p_model_layer3_0_bn2_weight = p_model_layer3_0_bn2_bias = b_model_layer3_0_bn2_running_mean = b_model_layer3_0_bn2_running_var = None
#                     getitem_33: "f16[1, 256, 14, 14]" = _native_batch_norm_legit_no_training_11[0];  _native_batch_norm_legit_no_training_11 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_12: "f16[1, 256, 14, 14]" = torch.ops.aten.conv2d.default(relu_8, p_model_layer3_0_downsample_0_weight, None, [2, 2]);  relu_8 = p_model_layer3_0_downsample_0_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_12 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_12, p_model_layer3_0_downsample_1_weight, p_model_layer3_0_downsample_1_bias, b_model_layer3_0_downsample_1_running_mean, b_model_layer3_0_downsample_1_running_var, 0.1, 1e-05);  conv2d_12 = p_model_layer3_0_downsample_1_weight = p_model_layer3_0_downsample_1_bias = b_model_layer3_0_downsample_1_running_mean = b_model_layer3_0_downsample_1_running_var = None
#                     getitem_36: "f16[1, 256, 14, 14]" = _native_batch_norm_legit_no_training_12[0];  _native_batch_norm_legit_no_training_12 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torchvision/models/resnet.py:102 in forward, code: out += identity
#                     add_9: "f16[1, 256, 14, 14]" = torch.ops.aten.add.Tensor(getitem_33, getitem_36);  getitem_33 = getitem_36 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_10: "f16[1, 256, 14, 14]" = torch.ops.aten.relu.default(add_9);  add_9 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_13: "f16[1, 256, 14, 14]" = torch.ops.aten.conv2d.default(relu_10, p_model_layer3_1_conv1_weight, None, [1, 1], [1, 1]);  p_model_layer3_1_conv1_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_13 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_13, p_model_layer3_1_bn1_weight, p_model_layer3_1_bn1_bias, b_model_layer3_1_bn1_running_mean, b_model_layer3_1_bn1_running_var, 0.1, 1e-05);  conv2d_13 = p_model_layer3_1_bn1_weight = p_model_layer3_1_bn1_bias = b_model_layer3_1_bn1_running_mean = b_model_layer3_1_bn1_running_var = None
#                     getitem_39: "f16[1, 256, 14, 14]" = _native_batch_norm_legit_no_training_13[0];  _native_batch_norm_legit_no_training_13 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_11: "f16[1, 256, 14, 14]" = torch.ops.aten.relu.default(getitem_39);  getitem_39 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_14: "f16[1, 256, 14, 14]" = torch.ops.aten.conv2d.default(relu_11, p_model_layer3_1_conv2_weight, None, [1, 1], [1, 1]);  relu_11 = p_model_layer3_1_conv2_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_14 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_14, p_model_layer3_1_bn2_weight, p_model_layer3_1_bn2_bias, b_model_layer3_1_bn2_running_mean, b_model_layer3_1_bn2_running_var, 0.1, 1e-05);  conv2d_14 = p_model_layer3_1_bn2_weight = p_model_layer3_1_bn2_bias = b_model_layer3_1_bn2_running_mean = b_model_layer3_1_bn2_running_var = None
#                     getitem_42: "f16[1, 256, 14, 14]" = _native_batch_norm_legit_no_training_14[0];  _native_batch_norm_legit_no_training_14 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torchvision/models/resnet.py:102 in forward, code: out += identity
#                     add_10: "f16[1, 256, 14, 14]" = torch.ops.aten.add.Tensor(getitem_42, relu_10);  getitem_42 = relu_10 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_12: "f16[1, 256, 14, 14]" = torch.ops.aten.relu.default(add_10);  add_10 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_15: "f16[1, 512, 7, 7]" = torch.ops.aten.conv2d.default(relu_12, p_model_layer4_0_conv1_weight, None, [2, 2], [1, 1]);  p_model_layer4_0_conv1_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_15 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_15, p_model_layer4_0_bn1_weight, p_model_layer4_0_bn1_bias, b_model_layer4_0_bn1_running_mean, b_model_layer4_0_bn1_running_var, 0.1, 1e-05);  conv2d_15 = p_model_layer4_0_bn1_weight = p_model_layer4_0_bn1_bias = b_model_layer4_0_bn1_running_mean = b_model_layer4_0_bn1_running_var = None
#                     getitem_45: "f16[1, 512, 7, 7]" = _native_batch_norm_legit_no_training_15[0];  _native_batch_norm_legit_no_training_15 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_13: "f16[1, 512, 7, 7]" = torch.ops.aten.relu.default(getitem_45);  getitem_45 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_16: "f16[1, 512, 7, 7]" = torch.ops.aten.conv2d.default(relu_13, p_model_layer4_0_conv2_weight, None, [1, 1], [1, 1]);  relu_13 = p_model_layer4_0_conv2_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_16 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_16, p_model_layer4_0_bn2_weight, p_model_layer4_0_bn2_bias, b_model_layer4_0_bn2_running_mean, b_model_layer4_0_bn2_running_var, 0.1, 1e-05);  conv2d_16 = p_model_layer4_0_bn2_weight = p_model_layer4_0_bn2_bias = b_model_layer4_0_bn2_running_mean = b_model_layer4_0_bn2_running_var = None
#                     getitem_48: "f16[1, 512, 7, 7]" = _native_batch_norm_legit_no_training_16[0];  _native_batch_norm_legit_no_training_16 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_17: "f16[1, 512, 7, 7]" = torch.ops.aten.conv2d.default(relu_12, p_model_layer4_0_downsample_0_weight, None, [2, 2]);  relu_12 = p_model_layer4_0_downsample_0_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_17 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_17, p_model_layer4_0_downsample_1_weight, p_model_layer4_0_downsample_1_bias, b_model_layer4_0_downsample_1_running_mean, b_model_layer4_0_downsample_1_running_var, 0.1, 1e-05);  conv2d_17 = p_model_layer4_0_downsample_1_weight = p_model_layer4_0_downsample_1_bias = b_model_layer4_0_downsample_1_running_mean = b_model_layer4_0_downsample_1_running_var = None
#                     getitem_51: "f16[1, 512, 7, 7]" = _native_batch_norm_legit_no_training_17[0];  _native_batch_norm_legit_no_training_17 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torchvision/models/resnet.py:102 in forward, code: out += identity
#                     add_11: "f16[1, 512, 7, 7]" = torch.ops.aten.add.Tensor(getitem_48, getitem_51);  getitem_48 = getitem_51 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
# ...
#                     getitem_54: "f16[1, 512, 7, 7]" = _native_batch_norm_legit_no_training_18[0];  _native_batch_norm_legit_no_training_18 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_15: "f16[1, 512, 7, 7]" = torch.ops.aten.relu.default(getitem_54);  getitem_54 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/conv.py:548 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_19: "f16[1, 512, 7, 7]" = torch.ops.aten.conv2d.default(relu_15, p_model_layer4_1_conv2_weight, None, [1, 1], [1, 1]);  relu_15 = p_model_layer4_1_conv2_weight = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:193 in forward, code: return F.batch_norm(
#                     _native_batch_norm_legit_no_training_19 = torch.ops.aten._native_batch_norm_legit_no_training.default(conv2d_19, p_model_layer4_1_bn2_weight, p_model_layer4_1_bn2_bias, b_model_layer4_1_bn2_running_mean, b_model_layer4_1_bn2_running_var, 0.1, 1e-05);  conv2d_19 = p_model_layer4_1_bn2_weight = p_model_layer4_1_bn2_bias = b_model_layer4_1_bn2_running_mean = b_model_layer4_1_bn2_running_var = None
#                     getitem_57: "f16[1, 512, 7, 7]" = _native_batch_norm_legit_no_training_19[0];  _native_batch_norm_legit_no_training_19 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torchvision/models/resnet.py:102 in forward, code: out += identity
#                     add_12: "f16[1, 512, 7, 7]" = torch.ops.aten.add.Tensor(getitem_57, relu_14);  getitem_57 = relu_14 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/activation.py:144 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_16: "f16[1, 512, 7, 7]" = torch.ops.aten.relu.default(add_12);  add_12 = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/pooling.py:1500 in forward, code: return F.adaptive_avg_pool2d(input, self.output_size)
#                     mean: "f16[1, 512, 1, 1]" = torch.ops.aten.mean.dim(relu_16, [-1, -2], True);  relu_16 = None
#
#                      # File: /tmp/ipykernel_726466/1062803002.py:31 in forward, code: x = torch.flatten(x, 1)
#                     view: "f16[1, 512]" = torch.ops.aten.view.default(mean, [1, 512]);  mean = None
#
#                      # File: /home/patryk-magisterka/Desktop/venv/ML_venv/lib/python3.12/site-packages/torch/nn/modules/linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#                     linear: "f16[1, 2]" = torch.ops.aten.linear.default(view, p_model_fc_weight, p_model_fc_bias);  view = p_model_fc_weight = p_model_fc_bias = None
#                     return (linear,)
#
#         Graph signature:
#             # inputs
#             p_model_conv1_weight: PARAMETER target='model.conv1.weight'
#             p_model_bn1_weight: PARAMETER target='model.bn1.weight'
#             p_model_bn1_bias: PARAMETER target='model.bn1.bias'
#             p_model_layer1_0_conv1_weight: PARAMETER target='model.layer1.0.conv1.weight'
#             p_model_layer1_0_bn1_weight: PARAMETER target='model.layer1.0.bn1.weight'
#             p_model_layer1_0_bn1_bias: PARAMETER target='model.layer1.0.bn1.bias'
#             p_model_layer1_0_conv2_weight: PARAMETER target='model.layer1.0.conv2.weight'
#             p_model_layer1_0_bn2_weight: PARAMETER target='model.layer1.0.bn2.weight'
#             p_model_layer1_0_bn2_bias: PARAMETER target='model.layer1.0.bn2.bias'
#             p_model_layer1_1_conv1_weight: PARAMETER target='model.layer1.1.conv1.weight'
#             p_model_layer1_1_bn1_weight: PARAMETER target='model.layer1.1.bn1.weight'
#             p_model_layer1_1_bn1_bias: PARAMETER target='model.layer1.1.bn1.bias'
#             p_model_layer1_1_conv2_weight: PARAMETER target='model.layer1.1.conv2.weight'
#             p_model_layer1_1_bn2_weight: PARAMETER target='model.layer1.1.bn2.weight'
#             p_model_layer1_1_bn2_bias: PARAMETER target='model.layer1.1.bn2.bias'
#             p_model_layer2_0_conv1_weight: PARAMETER target='model.layer2.0.conv1.weight'
#             p_model_layer2_0_bn1_weight: PARAMETER target='model.layer2.0.bn1.weight'
#             p_model_layer2_0_bn1_bias: PARAMETER target='model.layer2.0.bn1.bias'
#             p_model_layer2_0_conv2_weight: PARAMETER target='model.layer2.0.conv2.weight'
#             p_model_layer2_0_bn2_weight: PARAMETER target='model.layer2.0.bn2.weight'
#             p_model_layer2_0_bn2_bias: PARAMETER target='model.layer2.0.bn2.bias'
#             p_model_layer2_0_downsample_0_weight: PARAMETER target='model.layer2.0.downsample.0.weight'
#             p_model_layer2_0_downsample_1_weight: PARAMETER target='model.layer2.0.downsample.1.weight'
#             p_model_layer2_0_downsample_1_bias: PARAMETER target='model.layer2.0.downsample.1.bias'
#             p_model_layer2_1_conv1_weight: PARAMETER target='model.layer2.1.conv1.weight'
#             p_model_layer2_1_bn1_weight: PARAMETER target='model.layer2.1.bn1.weight'
#             p_model_layer2_1_bn1_bias: PARAMETER target='model.layer2.1.bn1.bias'
#             p_model_layer2_1_conv2_weight: PARAMETER target='model.layer2.1.conv2.weight'
#             p_model_layer2_1_bn2_weight: PARAMETER target='model.layer2.1.bn2.weight'
#             p_model_layer2_1_bn2_bias: PARAMETER target='model.layer2.1.bn2.bias'
#             p_model_layer3_0_conv1_weight: PARAMETER target='model.layer3.0.conv1.weight'
#             p_model_layer3_0_bn1_weight: PARAMETER target='model.layer3.0.bn1.weight'
#             p_model_layer3_0_bn1_bias: PARAMETER target='model.layer3.0.bn1.bias'
#             p_model_layer3_0_conv2_weight: PARAMETER target='model.layer3.0.conv2.weight'
#             p_model_layer3_0_bn2_weight: PARAMETER target='model.layer3.0.bn2.weight'
#             p_model_layer3_0_bn2_bias: PARAMETER target='model.layer3.0.bn2.bias'
#             p_model_layer3_0_downsample_0_weight: PARAMETER target='model.layer3.0.downsample.0.weight'
#             p_model_layer3_0_downsample_1_weight: PARAMETER target='model.layer3.0.downsample.1.weight'
#             p_model_layer3_0_downsample_1_bias: PARAMETER target='model.layer3.0.downsample.1.bias'
#             p_model_layer3_1_conv1_weight: PARAMETER target='model.layer3.1.conv1.weight'
#             p_model_layer3_1_bn1_weight: PARAMETER target='model.layer3.1.bn1.weight'
#             p_model_layer3_1_bn1_bias: PARAMETER target='model.layer3.1.bn1.bias'
#             p_model_layer3_1_conv2_weight: PARAMETER target='model.layer3.1.conv2.weight'
#             p_model_layer3_1_bn2_weight: PARAMETER target='model.layer3.1.bn2.weight'
#             p_model_layer3_1_bn2_bias: PARAMETER target='model.layer3.1.bn2.bias'
#             p_model_layer4_0_conv1_weight: PARAMETER target='model.layer4.0.conv1.weight'
#             p_model_layer4_0_bn1_weight: PARAMETER target='model.layer4.0.bn1.weight'
#             p_model_layer4_0_bn1_bias: PARAMETER target='model.layer4.0.bn1.bias'
#             p_model_layer4_0_conv2_weight: PARAMETER target='model.layer4.0.conv2.weight'
#             p_model_layer4_0_bn2_weight: PARAMETER target='model.layer4.0.bn2.weight'
#             p_model_layer4_0_bn2_bias: PARAMETER target='model.layer4.0.bn2.bias'
#             p_model_layer4_0_downsample_0_weight: PARAMETER target='model.layer4.0.downsample.0.weight'
#             p_model_layer4_0_downsample_1_weight: PARAMETER target='model.layer4.0.downsample.1.weight'
#             p_model_layer4_0_downsample_1_bias: PARAMETER target='model.layer4.0.downsample.1.bias'
#             p_model_layer4_1_conv1_weight: PARAMETER target='model.layer4.1.conv1.weight'
#             p_model_layer4_1_bn1_weight: PARAMETER target='model.layer4.1.bn1.weight'
#             p_model_layer4_1_bn1_bias: PARAMETER target='model.layer4.1.bn1.bias'
#             p_model_layer4_1_conv2_weight: PARAMETER target='model.layer4.1.conv2.weight'
#             p_model_layer4_1_bn2_weight: PARAMETER target='model.layer4.1.bn2.weight'
#             p_model_layer4_1_bn2_bias: PARAMETER target='model.layer4.1.bn2.bias'
#             p_model_fc_weight: PARAMETER target='model.fc.weight'
#             p_model_fc_bias: PARAMETER target='model.fc.bias'
#             b_model_bn1_running_mean: BUFFER target='model.bn1.running_mean' persistent=True
#             b_model_bn1_running_var: BUFFER target='model.bn1.running_var' persistent=True
#             b_model_bn1_num_batches_tracked: BUFFER target='model.bn1.num_batches_tracked' persistent=True
#             b_model_layer1_0_bn1_running_mean: BUFFER target='model.layer1.0.bn1.running_mean' persistent=True
#             b_model_layer1_0_bn1_running_var: BUFFER target='model.layer1.0.bn1.running_var' persistent=True
#             b_model_layer1_0_bn1_num_batches_tracked: BUFFER target='model.layer1.0.bn1.num_batches_tracked' persistent=True
#             b_model_layer1_0_bn2_running_mean: BUFFER target='model.layer1.0.bn2.running_mean' persistent=True
#             b_model_layer1_0_bn2_running_var: BUFFER target='model.layer1.0.bn2.running_var' persistent=True
#             b_model_layer1_0_bn2_num_batches_tracked: BUFFER target='model.layer1.0.bn2.num_batches_tracked' persistent=True
#             b_model_layer1_1_bn1_running_mean: BUFFER target='model.layer1.1.bn1.running_mean' persistent=True
#             b_model_layer1_1_bn1_running_var: BUFFER target='model.layer1.1.bn1.running_var' persistent=True
#             b_model_layer1_1_bn1_num_batches_tracked: BUFFER target='model.layer1.1.bn1.num_batches_tracked' persistent=True
#             b_model_layer1_1_bn2_running_mean: BUFFER target='model.layer1.1.bn2.running_mean' persistent=True
#             b_model_layer1_1_bn2_running_var: BUFFER target='model.layer1.1.bn2.running_var' persistent=True
#             b_model_layer1_1_bn2_num_batches_tracked: BUFFER target='model.layer1.1.bn2.num_batches_tracked' persistent=True
#             b_model_layer2_0_bn1_running_mean: BUFFER target='model.layer2.0.bn1.running_mean' persistent=True
#             b_model_layer2_0_bn1_running_var: BUFFER target='model.layer2.0.bn1.running_var' persistent=True
#             b_model_layer2_0_bn1_num_batches_tracked: BUFFER target='model.layer2.0.bn1.num_batches_tracked' persistent=True
#             b_model_layer2_0_bn2_running_mean: BUFFER target='model.layer2.0.bn2.running_mean' persistent=True
#             b_model_layer2_0_bn2_running_var: BUFFER target='model.layer2.0.bn2.running_var' persistent=True
#             b_model_layer2_0_bn2_num_batches_tracked: BUFFER target='model.layer2.0.bn2.num_batches_tracked' persistent=True
#             b_model_layer2_0_downsample_1_running_mean: BUFFER target='model.layer2.0.downsample.1.running_mean' persistent=True
#             b_model_layer2_0_downsample_1_running_var: BUFFER target='model.layer2.0.downsample.1.running_var' persistent=True
#             b_model_layer2_0_downsample_1_num_batches_tracked: BUFFER target='model.layer2.0.downsample.1.num_batches_tracked' persistent=True
#             b_model_layer2_1_bn1_running_mean: BUFFER target='model.layer2.1.bn1.running_mean' persistent=True
#             b_model_layer2_1_bn1_running_var: BUFFER target='model.layer2.1.bn1.running_var' persistent=True
#             b_model_layer2_1_bn1_num_batches_tracked: BUFFER target='model.layer2.1.bn1.num_batches_tracked' persistent=True
#             b_model_layer2_1_bn2_running_mean: BUFFER target='model.layer2.1.bn2.running_mean' persistent=True
#             b_model_layer2_1_bn2_running_var: BUFFER target='model.layer2.1.bn2.running_var' persistent=True
#             b_model_layer2_1_bn2_num_batches_tracked: BUFFER target='model.layer2.1.bn2.num_batches_tracked' persistent=True
#             b_model_layer3_0_bn1_running_mean: BUFFER target='model.layer3.0.bn1.running_mean' persistent=True
#             b_model_layer3_0_bn1_running_var: BUFFER target='model.layer3.0.bn1.running_var' persistent=True
#             b_model_layer3_0_bn1_num_batches_tracked: BUFFER target='model.layer3.0.bn1.num_batches_tracked' persistent=True
#             b_model_layer3_0_bn2_running_mean: BUFFER target='model.layer3.0.bn2.running_mean' persistent=True
#             b_model_layer3_0_bn2_running_var: BUFFER target='model.layer3.0.bn2.running_var' persistent=True
#             b_model_layer3_0_bn2_num_batches_tracked: BUFFER target='model.layer3.0.bn2.num_batches_tracked' persistent=True
#             b_model_layer3_0_downsample_1_running_mean: BUFFER target='model.layer3.0.downsample.1.running_mean' persistent=True
#             b_model_layer3_0_downsample_1_running_var: BUFFER target='model.layer3.0.downsample.1.running_var' persistent=True
#             b_model_layer3_0_downsample_1_num_batches_tracked: BUFFER target='model.layer3.0.downsample.1.num_batches_tracked' persistent=True
#             b_model_layer3_1_bn1_running_mean: BUFFER target='model.layer3.1.bn1.running_mean' persistent=True
#             b_model_layer3_1_bn1_running_var: BUFFER target='model.layer3.1.bn1.running_var' persistent=True
#             b_model_layer3_1_bn1_num_batches_tracked: BUFFER target='model.layer3.1.bn1.num_batches_tracked' persistent=True
#             b_model_layer3_1_bn2_running_mean: BUFFER target='model.layer3.1.bn2.running_mean' persistent=True
#             b_model_layer3_1_bn2_running_var: BUFFER target='model.layer3.1.bn2.running_var' persistent=True
#             b_model_layer3_1_bn2_num_batches_tracked: BUFFER target='model.layer3.1.bn2.num_batches_tracked' persistent=True
#             b_model_layer4_0_bn1_running_mean: BUFFER target='model.layer4.0.bn1.running_mean' persistent=True
#             b_model_layer4_0_bn1_running_var: BUFFER target='model.layer4.0.bn1.running_var' persistent=True
#             b_model_layer4_0_bn1_num_batches_tracked: BUFFER target='model.layer4.0.bn1.num_batches_tracked' persistent=True
#             b_model_layer4_0_bn2_running_mean: BUFFER target='model.layer4.0.bn2.running_mean' persistent=True
#             b_model_layer4_0_bn2_running_var: BUFFER target='model.layer4.0.bn2.running_var' persistent=True
#             b_model_layer4_0_bn2_num_batches_tracked: BUFFER target='model.layer4.0.bn2.num_batches_tracked' persistent=True
#             b_model_layer4_0_downsample_1_running_mean: BUFFER target='model.layer4.0.downsample.1.running_mean' persistent=True
#             b_model_layer4_0_downsample_1_running_var: BUFFER target='model.layer4.0.downsample.1.running_var' persistent=True
#             b_model_layer4_0_downsample_1_num_batches_tracked: BUFFER target='model.layer4.0.downsample.1.num_batches_tracked' persistent=True
#             b_model_layer4_1_bn1_running_mean: BUFFER target='model.layer4.1.bn1.running_mean' persistent=True
#             b_model_layer4_1_bn1_running_var: BUFFER target='model.layer4.1.bn1.running_var' persistent=True
#             b_model_layer4_1_bn1_num_batches_tracked: BUFFER target='model.layer4.1.bn1.num_batches_tracked' persistent=True
#             b_model_layer4_1_bn2_running_mean: BUFFER target='model.layer4.1.bn2.running_mean' persistent=True
#             b_model_layer4_1_bn2_running_var: BUFFER target='model.layer4.1.bn2.running_var' persistent=True
#             b_model_layer4_1_bn2_num_batches_tracked: BUFFER target='model.layer4.1.bn2.num_batches_tracked' persistent=True
#             x: USER_INPUT
#
#             # outputs
#             linear: USER_OUTPUT
#
#         Range constraints: {s77: VR[0, int_oo]}
#
# )

# %%
import onnxruntime as ort

session = ort.InferenceSession(
    "models/resnet18.onnx",
    providers=["CUDAExecutionProvider"]
)

print(session.get_providers())
# Out:
# ['CUDAExecutionProvider', 'CPUExecutionProvider']

# %%
outputs = session.run(
    None,                 # None = wszystkie outputy
    {"input": sample.cpu().numpy()}   # nazwa inputa z exportu
)

outputs[0].argmax(axis=1)
# Out:
# array([1])
